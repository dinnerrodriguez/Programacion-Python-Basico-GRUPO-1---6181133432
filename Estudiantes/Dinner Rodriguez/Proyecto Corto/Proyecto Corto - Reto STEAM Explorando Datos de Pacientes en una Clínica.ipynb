# %% [markdown]
# # Proyecto Corto: Explorando Datos de Pacientes en una Clínica
# ## Programacion Python Basico | ICAI - UNA
# ## Profesor: Ing. Andrés Mena Abarca
# ### <mark>**Nombre del estudiante:**</mark> Dinner Rodríguez Méndez
# * * *

# %% [markdown]
# ¡Bienvenidos al reto STEAM! Hoy serás parte de un equipo de científicos de datos que está desarrollando una aplicación para analizar los datos de los pacientes de una clínica. Este proyecto se integra dentro del enfoque STEAM, donde no solo usaremos habilidades de programación y análisis, sino también creatividad, visualización y reflexión crítica para mejorar la experiencia de salud.
#
# En este reto, utilizaremos **Python** para analizar datos clínicos reales y responder preguntas importantes sobre la salud de los pacientes. También diseñarás soluciones creativas y colaborarás con tus compañeros para mejorar la aplicación.
#
# ### Contexto:
#
# El director de la clínica te ha encargado que construyas un sistema que pueda analizar la información de los pacientes, entender las enfermedades tratadas, los medicamentos recetados y comparar pacientes.
#
# ### Objetivos del Reto:
# 1. Aplicar estructuras básicas de Python como listas y ciclos.
# 2. Leer datos desde un archivo JSON y almacenarlos en listas.
# 3. Realizar análisis de datos sobre enfermedades y medicamentos.
# 4. Visualizar y comunicar los resultados de manera creativa.
#
# ### Fase Creativa STEAM:
# - **Ciencia y Tecnología:** Analizarás los datos clínicos.
# - **Ingeniería:** Implementarás las soluciones utilizando estructuras de Python.
# - **Arte y Matemáticas:** Visualizarás los resultados de manera atractiva y clara.
#
# ¡Comencemos!
#
# ## Cargar y Leer los Datos de Pacientes

# %%
import json

# Lista para almacenar los datos
lineas = []

# Abrir el archivo y leerlo línea por línea
with open('clinica.json', 'r', encoding='utf-8') as file:
    # Cargar el contenido JSON del archivo
    lineas = json.load(file)

# Imprimir los datos de manera ordenada
for item in lineas:
    # Usamos un formato más claro para mostrar los datos de cada lista
    print(f"ID: {item[0]}, Teléfono: {item[1]}, Provincia: {item[2]}, Cantón: {item[3]}, Enfermedad: {item[4]}, Medicamento: {item[5]}")
# Out:
# ID: 123, Teléfono: 89076541, Provincia: Heredia, Cantón: Barva, Enfermedad: gripe, Medicamento: acetaminofen
# ID: 321, Teléfono: 31321321, Provincia: Cartago, Cantón: Pacayas, Enfermedad: gastritis, Medicamento: antiacido
# ID: 456, Teléfono: 87539856, Provincia: San Jose, Cantón: Pavas, Enfermedad: tos, Medicamento: jarabe
# ID: 789, Teléfono: 45522221, Provincia: Limón, Cantón: Puerto Viejo, Enfermedad: migraña, Medicamento: acetaminofen
# ID: 345, Teléfono: 45354632, Provincia: Guanacaste, Cantón: Liberia, Enfermedad: dolor, Medicamento: acetaminofen
# ID: 123, Teléfono: 89076541, Provincia: Heredia, Cantón: Barva, Enfermedad: migraña, Medicamento: acetaminofen
# ID: 456, Teléfono: 87539856, Provincia: San Jose, Cantón: Pavas, Enfermedad: dolor, Medicamento: acetaminofen
# ID: 456, Teléfono: 87539856, Provincia: San Jose, Cantón: Pavas, Enfermedad: dolor, Medicamento: jarabe
# ID: 345, Teléfono: 45354632, Provincia: Guanacaste, Cantón: Liberia, Enfermedad: gripe, Medicamento: acetaminofen
# ID: 789, Teléfono: 45522221, Provincia: Limón, Cantón: Puerto Viejo, Enfermedad: presion, Medicamento: acetaminofen

# %% [markdown]
# ## Desafío 1: Análisis Científico - Reporte de Enfermedades Tratadas
#
# Tu primer reto es analizar los datos de los pacientes para generar un reporte de las enfermedades tratadas en la clínica. Utiliza listas y ciclos para contar cuántos pacientes han sido tratados por cada enfermedad.
#
# ### Instrucciones:
#
# 1. Crea una lista vacía donde almacenarás las enfermedades.
# 2. Recorre los datos de los pacientes y extrae la enfermedad de cada paciente.
# 3. Cuenta cuántos pacientes han sido tratados por cada enfermedad.
# 4. Visualiza los resultados de manera clara utilizando la técnica que elijas (gráficos o tablas).
#
# ### Preguntas:
#
# - ¿Qué enfermedades son las más tratadas en la clínica?
# - ¿Hay alguna enfermedad que te sorprenda por su prevalencia?

# %% [markdown]
# ### **Paso a Paso para el Estudiante**
#
# #### **Paso 1: Crear las Listas**
#
# ###
#
# 1. **Objetivo:** Necesitamos dos listas para almacenar:
#
#     - Los nombres de las enfermedades.
#     - La cantidad de veces que cada enfermedad aparece.
# 2. **Instrucción:**
#
#     - Crea una lista vacía llamada `lista_enfermedades`.
#     - Crea otra lista vacía llamada `lista_cantidades`.

# %%
# Lista para almacenar las enfermedades y sus cantidades

# Recorrer cada línea para contar las enfermedades
# Diccionario para almacenar las enfermedades y sus cantidades
enfermedades = {}

for item in lineas:
    enfermedad = item[4]  # El nombre de la enfermedad está en el índice 4
    if enfermedad in enfermedades:
        # Si la enfermedad ya está en el diccionario, aumentar su cantidad
        enfermedades[enfermedad] += 1
    else:
        # Si la enfermedad no está en el diccionario, agregarla con cantidad 1
        enfermedades[enfermedad] = 1

# Separar las enfermedades y sus cantidades en listas
lista_enfermedades = list(enfermedades.keys())
lista_cantidades = list(enfermedades.values())

# Imprimir las listas para verificar
print("Enfermedades:", lista_enfermedades)
print("Cantidades:", lista_cantidades)
# Out:
# Enfermedades: ['gripe', 'gastritis', 'tos', 'migraña', 'dolor', 'presion']
# Cantidades: [2, 1, 1, 2, 3, 1]

# %% [markdown]
# #### **Paso 2: Recorrer los Datos de los Pacientes**
#
# ###
#
# 1. **Objetivo:** Vamos a analizar cada paciente para extraer su enfermedad.
#
# 2. **Instrucción:**
#
#     - Usa un bucle `for` para recorrer cada `paciente` en `datos_pacientes` (ya está definida en el código como una lista de listas).
#     - Dentro del bucle, asigna la enfermedad del paciente (índice `4` de cada lista) a una variable llamada `enfermedad`.

# %%
# Extraemos la enfermedad del paciente
#Puedes imprimir el for para ver los datos que se procesan

# Suponiendo que ya tenemos los datos de los pacientes en la lista `datos_pacientes`
datos_pacientes = [
    ["123", 89076541, "Heredia", "Barva", "gripe", "acetaminofen"],
    ["321", 31321321, "Cartago", "Pacayas", "gastritis", "antiacido"],
    ["456", 87539856, "San Jose", "Pavas", "tos", "jarabe"],
    ["789", 45522221, "Limón", "Puerto Viejo", "migraña", "acetaminofen"],
    ["345", 45354632, "Guanacaste", "Liberia", "dolor", "acetaminofen"],
    ["123", 89076541, "Heredia", "Barva", "migraña", "acetaminofen"],
    ["456", 87539856, "San Jose", "Pavas", "dolor", "acetaminofen"],
    ["456", 87539856, "San Jose", "Pavas", "dolor", "jarabe"],
    ["345", 45354632, "Guanacaste", "Liberia", "gripe", "acetaminofen"],
    ["789", 45522221, "Limón", "Puerto Viejo", "presion", "acetaminofen"]
]

# Recorrer los datos de los pacientes
for paciente in datos_pacientes:
    # Asignar la enfermedad del paciente (índice 4)
    enfermedad = paciente[4]
    
    # Imprimir la enfermedad para verificar
    print(f"Enfermedad del paciente: {enfermedad}")
# Out:
# Enfermedad del paciente: gripe
# Enfermedad del paciente: gastritis
# Enfermedad del paciente: tos
# Enfermedad del paciente: migraña
# Enfermedad del paciente: dolor
# Enfermedad del paciente: migraña
# Enfermedad del paciente: dolor
# Enfermedad del paciente: dolor
# Enfermedad del paciente: gripe
# Enfermedad del paciente: presion

# %% [markdown]
# #### **Paso 3: Verificar si la Enfermedad ya Está en la Lista**
#
# 1. **Objetivo:** Verificar si la enfermedad ya fue registrada.
#
# 2. **Instrucción:**
#
#     - Usa un `if` para verificar si la `enfermedad` ya está en `lista_enfermedades`.
#     - Si **no** está en `lista_enfermedades`, agrega la enfermedad a `lista_enfermedades` y añade `1` a `lista_cantidades` para contarla por primera vez.
#     - Si **sí** está en `lista_enfermedades`, encuentra la posición (`indice`) de la enfermedad en `lista_enfermedades` y aumenta en `1` el valor en `lista_cantidades` en la misma posición.

# %%
# Pista: Usa `in` para verificar si la enfermedad ya está en lista_enfermedades.
# Pista: Si la enfermedad no está, agrégala a lista_enfermedades y empieza el conteo en lista_cantidades.
# Pista: Si la enfermedad ya está, usa `index` para encontrar su posición en lista_enfermedades y suma 1 en lista_cantidades en esa posición.

# Verificar si la enfermedad ya está en lista_enfermedades
if enfermedad not in lista_enfermedades:
    # Si no está, agregarla a lista_enfermedades y agregar 1 a lista_cantidades
    lista_enfermedades.append(enfermedad)
    lista_cantidades.append(1)
else:
        # Si ya está, encontrar el índice de la enfermedad y aumentar su cantidad en lista_cantidades
        indice = lista_enfermedades.index(enfermedad)
        lista_cantidades[indice] += 1

# Imprimir los resultados para verificar
print("Enfermedades:", lista_enfermedades)
print("Cantidades:", lista_cantidades)
# Out:
# Enfermedades: ['gripe', 'gastritis', 'tos', 'migraña', 'dolor', 'presion']
# Cantidades: [2, 1, 1, 2, 3, 3]

# %% [markdown]
# #### **Paso 4: Imprimir el Reporte Final**
#
# 1. **Objetivo:** Mostrar el número de pacientes con cada enfermedad.
#
# 2. **Instrucción:**
#
#     - Usa un bucle `for` para recorrer la lista `lista_enfermedades`.
#     - En cada iteración, imprime la enfermedad y el número de pacientes (que está en `lista_cantidades` en la misma posición).

# %%
print("Reporte de enfermedades tratadas:")

for i in range(len(lista_enfermedades)):
    # Obtener la enfermedad y la cantidad de pacientes
    enfermedad = lista_enfermedades[i]
    cantidad = lista_cantidades[i]
    
    # Imprimir el reporte de cada enfermedad
    print(f"{enfermedad}: {cantidad} pacientes")
# Out:
# Reporte de enfermedades tratadas:
# gripe: 2 pacientes
# gastritis: 1 pacientes
# tos: 1 pacientes
# migraña: 2 pacientes
# dolor: 3 pacientes
# presion: 2 pacientes

# %% [markdown]
# ### **Resumen Completo del Código**
#
# En ésta celda resume el código completo que debería tener al final para la solución del ejercicio:

# %%
#Esta parte puedes colocar todos los bloques de las celdas anteriores

import json

# Lista para almacenar los datos
lineas = []

# Abrir el archivo y leerlo línea por línea
with open('clinica.json', 'r', encoding='utf-8') as file:
    # Cargar el contenido JSON del archivo
    lineas = json.load(file)

# Imprimir los datos de manera ordenada
for item in lineas:
    # Usamos un formato más claro para mostrar los datos de cada lista
    print(f"ID: {item[0]}, Teléfono: {item[1]}, Provincia: {item[2]}, Cantón: {item[3]}, Enfermedad: {item[4]}, Medicamento: {item[5]}")
    
# Lista para almacenar las enfermedades y sus cantidades

# Recorrer cada línea para contar las enfermedades
# Diccionario para almacenar las enfermedades y sus cantidades
enfermedades = {}

for item in lineas:
    enfermedad = item[4]  # El nombre de la enfermedad está en el índice 4
    if enfermedad in enfermedades:
        # Si la enfermedad ya está en el diccionario, aumentar su cantidad
        enfermedades[enfermedad] += 1
    else:
        # Si la enfermedad no está en el diccionario, agregarla con cantidad 1
        enfermedades[enfermedad] = 1

# Separar las enfermedades y sus cantidades en listas
lista_enfermedades = list(enfermedades.keys())
lista_cantidades = list(enfermedades.values())

# Imprimir las listas para verificar
print("Enfermedades:", lista_enfermedades)
print("Cantidades:", lista_cantidades)

# Extraemos la enfermedad del paciente
#Puedes imprimir el for para ver los datos que se procesan

# Suponiendo que ya tenemos los datos de los pacientes en la lista `datos_pacientes`
datos_pacientes = [
    ["123", 89076541, "Heredia", "Barva", "gripe", "acetaminofen"],
    ["321", 31321321, "Cartago", "Pacayas", "gastritis", "antiacido"],
    ["456", 87539856, "San Jose", "Pavas", "tos", "jarabe"],
    ["789", 45522221, "Limón", "Puerto Viejo", "migraña", "acetaminofen"],
    ["345", 45354632, "Guanacaste", "Liberia", "dolor", "acetaminofen"],
    ["123", 89076541, "Heredia", "Barva", "migraña", "acetaminofen"],
    ["456", 87539856, "San Jose", "Pavas", "dolor", "acetaminofen"],
    ["456", 87539856, "San Jose", "Pavas", "dolor", "jarabe"],
    ["345", 45354632, "Guanacaste", "Liberia", "gripe", "acetaminofen"],
    ["789", 45522221, "Limón", "Puerto Viejo", "presion", "acetaminofen"]
]

# Recorrer los datos de los pacientes
for paciente in datos_pacientes:
    # Asignar la enfermedad del paciente (índice 4)
    enfermedad = paciente[4]
    
    # Imprimir la enfermedad para verificar
    print(f"Enfermedad del paciente: {enfermedad}")

# Pista: Usa `in` para verificar si la enfermedad ya está en lista_enfermedades.
# Pista: Si la enfermedad no está, agrégala a lista_enfermedades y empieza el conteo en lista_cantidades.
# Pista: Si la enfermedad ya está, usa `index` para encontrar su posición en lista_enfermedades y suma 1 en lista_cantidades en esa posición.

# Verificar si la enfermedad ya está en lista_enfermedades
if enfermedad not in lista_enfermedades:
    # Si no está, agregarla a lista_enfermedades y agregar 1 a lista_cantidades
    lista_enfermedades.append(enfermedad)
    lista_cantidades.append(1)
else:
        # Si ya está, encontrar el índice de la enfermedad y aumentar su cantidad en lista_cantidades
        indice = lista_enfermedades.index(enfermedad)
        lista_cantidades[indice] += 1

# Imprimir los resultados para verificar
print("Enfermedades:", lista_enfermedades)
print("Cantidades:", lista_cantidades)

print("Reporte de enfermedades tratadas:")

for i in range(len(lista_enfermedades)):
    # Obtener la enfermedad y la cantidad de pacientes
    enfermedad = lista_enfermedades[i]
    cantidad = lista_cantidades[i]
    
    # Imprimir el reporte de cada enfermedad
    print(f"{enfermedad}: {cantidad} pacientes")
# Out:
# ID: 123, Teléfono: 89076541, Provincia: Heredia, Cantón: Barva, Enfermedad: gripe, Medicamento: acetaminofen
# ID: 321, Teléfono: 31321321, Provincia: Cartago, Cantón: Pacayas, Enfermedad: gastritis, Medicamento: antiacido
# ID: 456, Teléfono: 87539856, Provincia: San Jose, Cantón: Pavas, Enfermedad: tos, Medicamento: jarabe
# ID: 789, Teléfono: 45522221, Provincia: Limón, Cantón: Puerto Viejo, Enfermedad: migraña, Medicamento: acetaminofen
# ID: 345, Teléfono: 45354632, Provincia: Guanacaste, Cantón: Liberia, Enfermedad: dolor, Medicamento: acetaminofen
# ID: 123, Teléfono: 89076541, Provincia: Heredia, Cantón: Barva, Enfermedad: migraña, Medicamento: acetaminofen
# ID: 456, Teléfono: 87539856, Provincia: San Jose, Cantón: Pavas, Enfermedad: dolor, Medicamento: acetaminofen
# ID: 456, Teléfono: 87539856, Provincia: San Jose, Cantón: Pavas, Enfermedad: dolor, Medicamento: jarabe
# ID: 345, Teléfono: 45354632, Provincia: Guanacaste, Cantón: Liberia, Enfermedad: gripe, Medicamento: acetaminofen
# ID: 789, Teléfono: 45522221, Provincia: Limón, Cantón: Puerto Viejo, Enfermedad: presion, Medicamento: acetaminofen
# Enfermedades: ['gripe', 'gastritis', 'tos', 'migraña', 'dolor', 'presion']
# Cantidades: [2, 1, 1, 2, 3, 1]
# Enfermedad del paciente: gripe
# Enfermedad del paciente: gastritis
# Enfermedad del paciente: tos
# Enfermedad del paciente: migraña
# Enfermedad del paciente: dolor
# Enfermedad del paciente: migraña
# Enfermedad del paciente: dolor
# Enfermedad del paciente: dolor
# Enfermedad del paciente: gripe
# Enfermedad del paciente: presion
# Enfermedades: ['gripe', 'gastritis', 'tos', 'migraña', 'dolor', 'presion']
# Cantidades: [2, 1, 1, 2, 3, 2]
# Reporte de enfermedades tratadas:
# gripe: 2 pacientes
# gastritis: 1 pacientes
# tos: 1 pacientes
# migraña: 2 pacientes
# dolor: 3 pacientes
# presion: 2 pacientes

# %% [markdown]
# ## Desafío 2: Exploración Tecnológica - Reporte de Medicamentos Recetados
#
# Ahora que ya tienes el reporte de las enfermedades tratadas, es momento de explorar qué medicamentos se están recetando en la clínica. Tu tarea es generar un reporte similar al anterior, pero esta vez debes contar cuántos pacientes han recibido cada medicamento.
#
# ### Instrucciones:
#
# 1. Almacena los medicamentos recetados en una lista.
# 2. Recorre los datos y cuenta cuántos pacientes han recibido cada medicamento.
# 3. Visualiza los resultados de manera creativa.
#
# ### Preguntas:
#
# - ¿Qué medicamentos son los más recetados?
# - ¿Cómo podrías optimizar el uso de medicamentos en la clínica?
#
# Resultados esperados:
#
# ```
# Reporte de medicamentos recetados:
# acetaminofen: 9 pacientes
# antiácido: 2 pacientes
# jarabe: 2 pacientes
# insulina: 3 pacientes
# salbutamol: 4 pacientes
# levotiroxina: 2 pacientes
# ............................................
#
# ```

# %%
datos_pacientes = [
    ["116640019", 61727979, "San José", "Desamparados", "gripe", "acetaminofen"],
    ["603240305", 60534319, "Heredia", "Santo Domingo", "gastritis", "antiácido"],
    ["503980535", 70713699, "Alajuela", "San Carlos", "tos", "jarabe"],
    ["702370234", 70693575, "Cartago", "Paraíso", "migraña", "acetaminofen"],
    ["116310912", 88070036, "San José", "Curridabat", "dolor", "acetaminofen"],
    ["604830325", 83155658, "Puntarenas", "Osa", "gripe", "acetaminofen"],
    ["116130052", 64069212, "Guanacaste", "Liberia", "gastritis", "antiácido"],
    ["111860150", 88447416, "Limón", "Puerto Viejo", "diabetes", "insulina"],
    ["110283", 61088556, "San José", "Escazú", "asma", "salbutamol"],
    ["503810832", 83076969, "Heredia", "Barva", "gripe", "acetaminofen"],
    ["114740407", 70112487, "Cartago", "Turrialba", "hipotiroidismo", "levotiroxina"],
    ["205750691", 83349456, "San José", "Montes de Oca", "alergias", "loratadina"],
    ["215487963", 78823654, "Guanacaste", "Nicoya", "migraña", "acetaminofen"],
    ["318540762", 65892345, "Alajuela", "Grecia", "presión alta", "amlodipino"],
    ["457821904", 72908475, "Cartago", "Oreamuno", "dolor de espalda", "ibuprofeno"],
    ["602948176", 61928374, "Heredia", "Belén", "ansiedad", "clonazepam"],
    ["703219485", 63487294, "Limón", "Guápiles", "diabetes", "insulina"],
    ["825613092", 72845312, "Puntarenas", "Coto Brus", "asma", "salbutamol"],
    ["908124753", 71239485, "San José", "Moravia", "alergias", "cetirizina"],
    ["103927564", 63749562, "Heredia", "San Isidro", "gastritis", "omeprazol"],
    ["200145879", 78546932, "Guanacaste", "Santa Cruz", "presión alta", "losartán"],
    ["305946278", 65849371, "Puntarenas", "Golfito", "tos", "jarabe"],
    ["412598764", 73284956, "San José", "Tibás", "dolor de espalda", "paracetamol"],
    ["507812394", 69231875, "Cartago", "El Guarco", "ansiedad", "diazepam"],
    ["602938574", 61249375, "Limón", "Siquirres", "diabetes", "metformina"],
    ["715498372", 74938261, "Alajuela", "Atenas", "asma", "fluticasona"],
    ["823654091", 69829375, "San José", "Pérez Zeledón", "alergias", "loratadina"],
    ["912475683", 73485629, "Cartago", "Jiménez", "hipotiroidismo", "levotiroxina"],
    ["104598273", 68597312, "Heredia", "San Rafael", "gripe", "acetaminofen"],
    ["205963184", 71928364, "Puntarenas", "Esparza", "gastritis", "pantoprazol"],
    ["301456897", 64395721, "San José", "Alajuelita", "migraña", "ibuprofeno"],
    ["401598723", 71928574, "Limón", "Matina", "presión alta", "enalapril"],
    ["510298374", 62938475, "Guanacaste", "Bagaces", "asma", "salbutamol"],
    ["621095837", 75928346, "Cartago", "Turrialba", "diabetes", "insulina"],
    ["732145609", 68495731, "Heredia", "Flores", "dolor", "acetaminofen"],
    ["802149357", 72938475, "San José", "Goicoechea", "gastritis", "omeprazol"],
    ["913256748", 65849371, "Puntarenas", "Buenos Aires", "presión alta", "amlodipino"],
    ["102548397", 67293857, "Limón", "Talamanca", "asma", "salbutamol"],
    ["204985763", 74583925, "Guanacaste", "Carrillo", "gripe", "acetaminofen"]
]



# Listas para almacenar los medicamentos y sus frecuencias
medicamentos = []
frecuencias = []

# Paso 2: Recorrer los datos de los pacientes
for paciente in datos_pacientes:
    # Asignar el medicamento recetado (índice 5)
    medicamento = paciente[5]
    
    # Verificar si el medicamento ya está en lista_medicamentos
    if medicamento not in medicamentos:
        # Si no está, agregarlo a lista_medicamentos y agregar 1 a medicamentos
        medicamentos.append(medicamento)
        frecuencias.append(1)
    else:
        # Si ya está, encontrar el índice del medicamento y aumentar su cantidad en frecuencia
        indice = medicamentos.index(medicamento)
        frecuencias[indice] += 1

# Paso 3: Imprimir el reporte final de medicamentos recetados
print("Reporte de medicamentos recetados:")
for i in range(len(medicamentos)):
    # Obtener el medicamento y la cantidad de pacientes
    medicamento = medicamentos[i]
    frecuencia = frecuencias[i]
    
    # Imprimir el reporte de cada medicamento
    print(f"{medicamento}: {frecuencia} pacientes")
# Out:
# Reporte de medicamentos recetados:
# acetaminofen: 9 pacientes
# antiácido: 2 pacientes
# jarabe: 2 pacientes
# insulina: 3 pacientes
# salbutamol: 4 pacientes
# levotiroxina: 2 pacientes
# loratadina: 2 pacientes
# amlodipino: 2 pacientes
# ibuprofeno: 2 pacientes
# clonazepam: 1 pacientes
# cetirizina: 1 pacientes
# omeprazol: 2 pacientes
# losartán: 1 pacientes
# paracetamol: 1 pacientes
# diazepam: 1 pacientes
# metformina: 1 pacientes
# fluticasona: 1 pacientes
# pantoprazol: 1 pacientes
# enalapril: 1 pacientes

# %% [markdown]
# ## Desafío 3: Ingeniería - Comparar Pacientes por Identificación
#
# Este desafío te permitirá comparar dos pacientes de la clínica en base a sus identificaciones. Tu objetivo es averiguar:
#
# 1. **¿Qué enfermedades tienen en común?**
# 2. **¿Qué medicamentos toman en común?**
#
# ### Instrucciones:
#
# 1. Solicita dos identificaciones de pacientes al usuario.
# 2. Extrae las enfermedades y medicamentos de esos dos pacientes.
# 3. Compara las enfermedades y medicamentos y muestra los resultados.
#
# ### Preguntas:
#
# - ¿Qué enfermedades y medicamentos son comunes en los pacientes comparados?
# - ¿Qué información adicional podrías incluir para mejorar esta comparación?

# %%
# Pedimos las identificaciones de los dos pacientes

id_paciente1 = input("Ingrese la identificación del primer paciente: ")
id_paciente2 = input("Ingrese la identificación del segundo paciente: ")

# Extraer las enfermedades y medicamentos de los pacientes seleccionados
enfermedades_paciente1 = set()
medicamentos_paciente1 = set()
enfermedades_paciente2 = set()
medicamentos_paciente2 = set()

# Recorrer los datos para encontrar las enfermedades y medicamentos de cada paciente
for paciente in datos_pacientes:
    if paciente[0] == id_paciente1:
        enfermedades_paciente1.add(paciente[4])
        medicamentos_paciente1.add(paciente[5])
    if paciente[0] == id_paciente2:
        enfermedades_paciente2.add(paciente[4])
        medicamentos_paciente2.add(paciente[5])

# Comparar las enfermedades y medicamentos
enfermedades_comunes = enfermedades_paciente1.intersection(enfermedades_paciente2)
medicamentos_comunes = medicamentos_paciente1.intersection(medicamentos_paciente2)

# Mostrar los resultados
print("\nComparación de pacientes:")
print(f"\nEnfermedades en común entre {id_paciente1} y {id_paciente2}:", end=" ")
if enfermedades_comunes:
    for enfermedad in enfermedades_comunes:
        print(f"['{enfermedad}']")
else:
    print("No tienen enfermedades comunes.")

print(f"\nMedicamentos en común entre {id_paciente1} y {id_paciente2}:", end=" ")
if medicamentos_comunes:
    for medicamento in medicamentos_comunes:
        print(f"['{medicamento}']")
else:
    print("No tienen medicamentos comunes.")




"""
Prueba con 702370234 - 215487963
Salida esperada
Enfermedades en común entre 702370234 y 215487963: ['migraña']
Medicamentos en común entre 702370234 y 215487963: ['acetaminofen']
"""

# %% [markdown]
# ## Desafío Final: Arte y Matemáticas - Visualización Creativa y Reflexión
#
# Has llegado al último desafío, ¡felicidades! Ahora es momento de presentar tus resultados de una forma creativa. Tu tarea será utilizar **gráficos**, **tablas** o incluso **arte digital** para mostrar tus descubrimientos sobre los datos de los pacientes de la clínica.
#
#
# ### Preguntas:
#
# - ¿Qué patrones encontraste en los datos?
# - ¿Cómo podrías usar estos análisis para mejorar la atención de los pacientes?

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Lista de pacientes (simulada)
datos_pacientes = [
    ["116640019", 61727979, "San José", "Desamparados", "gripe", "acetaminofen"],
    ["603240305", 60534319, "Heredia", "Santo Domingo", "gastritis", "antiácido"],
    ["503980535", 70713699, "Alajuela", "San Carlos", "tos", "jarabe"],
    ["702370234", 70693575, "Cartago", "Paraíso", "migraña", "acetaminofen"],
    ["116310912", 88070036, "San José", "Curridabat", "dolor", "acetaminofen"],
    ["604830325", 83155658, "Puntarenas", "Osa", "gripe", "acetaminofen"],
    ["116130052", 64069212, "Guanacaste", "Liberia", "gastritis", "antiácido"],
    ["111860150", 88447416, "Limón", "Puerto Viejo", "diabetes", "insulina"],
    ["110283", 61088556, "San José", "Escazú", "asma", "salbutamol"],
    ["503810832", 83076969, "Heredia", "Barva", "gripe", "acetaminofen"],
    ["114740407", 70112487, "Cartago", "Turrialba", "hipotiroidismo", "levotiroxina"],
    ["205750691", 83349456, "San José", "Montes de Oca", "alergias", "loratadina"],
    ["215487963", 78823654, "Guanacaste", "Nicoya", "migraña", "acetaminofen"],
    ["318540762", 65892345, "Alajuela", "Grecia", "presión alta", "amlodipino"],
    ["457821904", 72908475, "Cartago", "Oreamuno", "dolor de espalda", "ibuprofeno"],
    ["602948176", 61928374, "Heredia", "Belén", "ansiedad", "clonazepam"],
    ["703219485", 63487294, "Limón", "Guápiles", "diabetes", "insulina"],
    ["825613092", 72845312, "Puntarenas", "Coto Brus", "asma", "salbutamol"],
    ["908124753", 71239485, "San José", "Moravia", "alergias", "cetirizina"],
    ["103927564", 63749562, "Heredia", "San Isidro", "gastritis", "omeprazol"],
    ["200145879", 78546932, "Guanacaste", "Santa Cruz", "presión alta", "losartán"],
    ["305946278", 65849371, "Puntarenas", "Golfito", "tos", "jarabe"],
    ["412598764", 73284956, "San José", "Tibás", "dolor de espalda", "paracetamol"],
    ["507812394", 69231875, "Cartago", "El Guarco", "ansiedad", "diazepam"],
    ["602938574", 61249375, "Limón", "Siquirres", "diabetes", "metformina"],
    ["715498372", 74938261, "Alajuela", "Atenas", "asma", "fluticasona"],
    ["823654091", 69829375, "San José", "Pérez Zeledón", "alergias", "loratadina"],
    ["912475683", 73485629, "Cartago", "Jiménez", "hipotiroidismo", "levotiroxina"],
    ["104598273", 68597312, "Heredia", "San Rafael", "gripe", "acetaminofen"],
    ["205963184", 71928364, "Puntarenas", "Esparza", "gastritis", "pantoprazol"],
    ["301456897", 64395721, "San José", "Alajuelita", "migraña", "ibuprofeno"],
    ["401598723", 71928574, "Limón", "Matina", "presión alta", "enalapril"],
    ["510298374", 62938475, "Guanacaste", "Bagaces", "asma", "salbutamol"],
    ["621095837", 75928346, "Cartago", "Turrialba", "diabetes", "insulina"],
    ["732145609", 68495731, "Heredia", "Flores", "dolor", "acetaminofen"],
    ["802149357", 72938475, "San José", "Goicoechea", "gastritis", "omeprazol"],
    ["913256748", 65849371, "Puntarenas", "Buenos Aires", "presión alta", "amlodipino"],
    ["102548397", 67293857, "Limón", "Talamanca", "asma", "salbutamol"],
    ["204985763", 74583925, "Guanacaste", "Carrillo", "gripe", "acetaminofen"]
]

# Paso 1: Crear las listas de enfermedades y medicamentos con sus frecuencias
enfermedades = []
medicamentos = []

# Recorrer los datos de los pacientes para extraer enfermedades y medicamentos
for paciente in datos_pacientes:
    enfermedades.append(paciente[4])
    medicamentos.append(paciente[5])

# Paso 2: Contar las ocurrencias de cada enfermedad y medicamento
df_enfermedades = pd.DataFrame(enfermedades, columns=["Enfermedad"])
df_medicamentos = pd.DataFrame(medicamentos, columns=["Medicamento"])

# Contamos las ocurrencias (frecuencia) de cada enfermedad y medicamento
enfermedades_frecuencia = df_enfermedades["Enfermedad"].value_counts()
medicamentos_frecuencia = df_medicamentos["Medicamento"].value_counts()

# Paso 3: Crear gráficos para las visualizaciones

# Gráfico de barras para enfermedades más comunes
plt.figure(figsize=(10, 6))
enfermedades_frecuencia.plot(kind='bar', color='skyblue')
plt.title("Enfermedades más comunes")
plt.xlabel("Enfermedades")
plt.ylabel("Número de Pacientes")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# Gráfico de barras para medicamentos más recetados
plt.figure(figsize=(10, 6))
medicamentos_frecuencia.plot(kind='bar', color='lightgreen')
plt.title("Medicamentos más recetados")
plt.xlabel("Medicamentos")
plt.ylabel("Número de Pacientes")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# Gráfico de pie (pastel) para distribución de enfermedades
plt.figure(figsize=(8, 8))
enfermedades_frecuencia.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['lightcoral', 'lightblue', 'lightgreen', 'orange', 'gold', 'lightpink'])
plt.title("Distribución de Enfermedades")
plt.ylabel('')  # Eliminamos la etiqueta de la leyenda
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# Gráfico de pie (pastel) para distribución de medicamentos
plt.figure(figsize=(8, 8))
medicamentos_frecuencia.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0'])
plt.title("Distribución de Medicamentos Recetados")
plt.ylabel('')  # Eliminamos la etiqueta de la leyenda
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # Explicación del código:
# 1. Crear las listas de enfermedades y medicamentos: Extraemos los datos de enfermedades y medicamentos de la lista datos_pacientes.
#
# 2. Contar las ocurrencias: Usamos pandas para contar las frecuencias de cada enfermedad y medicamento.
# 3. Gráficos:
#     * Gráfico de barras para las enfermedades y medicamentos más comunes.
#     * Gráfico de pie (pastel) para mostrar la distribución de enfermedades y medicamentos de manera visual.
# 4. Visualización: Los gráficos nos ayudan a identificar rápidamente qué enfermedades son más comunes y qué medicamentos se están recetando más.
#
# # Resultados esperados:
# 1. Gráfico de barras de enfermedades más comunes: Este gráfico mostrará qué enfermedades son más frecuentes entre los pacientes, lo que puede indicar problemas recurrentes en la población atendida.
#
# 2. Gráfico de barras de medicamentos más recetados: Nos dará una visión clara de qué medicamentos se utilizan con mayor frecuencia, lo que puede ayudar a evaluar el stock necesario y si existen medicamentos que podrían estar siendo recetados de forma innecesaria.
#
# 3. Gráfico de pie (pastel) de distribución de enfermedades: Este gráfico es útil para ver cómo se distribuyen las enfermedades en términos porcentuales. Si una enfermedad ocupa una gran parte del gráfico, puede señalar que es muy común entre los pacientes.
#
# 4. Gráfico de pie (pastel) de distribución de medicamentos: Muestra la proporción de pacientes que recibieron cada medicamento, ayudando a identificar patrones de prescripción.
#
# # Reflexión y respuesta a las preguntas:
# ## * ¿Qué patrones encontraste en los datos?
#
# * En el caso de las enfermedades, puede que veamos que "gripe" y "migraña" son las más comunes. Esto podría indicar que el clima o factores estacionales están influyendo.
# * En cuanto a los medicamentos, "acetaminofen" podría ser el más recetado, lo que sugiere que se utiliza para una variedad de síntomas comunes.
# ## * ¿Cómo podrías usar estos análisis para mejorar la atención de los pacientes?
#
# * Optimización del inventario: Conociendo los medicamentos más recetados, podemos asegurarnos de tener suficiente stock de los más utilizados, como el acetaminofen.
# * Enfermedades comunes: Si sabemos que ciertas enfermedades son más frecuentes, podemos ajustar las campañas de prevención o dirigir recursos adicionales hacia esos casos, como campañas de vacunación o educación sobre prevención.
# * Reducción de medicamentos innecesarios: Si algunos medicamentos están siendo recetados con demasiada frecuencia (como acetaminofen), se podría evaluar si se están utilizando correctamente o si existen alternativas menos costosas o más eficaces.
